# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import csv
import seaborn as sb
import re
import seaborn as sns
import itertools

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report, precision_score, recall_score 
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn import metrics
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix as cm
from sklearn.naive_bayes import MultinomialNB
from nltk.tokenize import word_tokenize
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import LogisticRegression

# %%
# read files
True_news = pd.read_csv('/kaggle/input/datdset/True.csv')
Fake_news = pd.read_csv('/kaggle/input/datdset/Fake.csv')

# %%
# create label that take value true at 0

True_news['label'] = 0

# create label that take value false at 1

Fake_news['label'] = 1

# %%
# check the if data in files read probably and print first 10 records
True_news.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# 5  WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...  politicsNews
# 6  WEST PALM BEACH, Fla (Reuters) - President Don...  politicsNews
# 7  The following statements were posted to the ve...  politicsNews
# 8  The following statements were posted to the ve...  politicsNews
# 9  WASHINGTON (Reuters) - Alabama Secretary of St...  politicsNews
#
#                  date  label
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0
# 5  December 29, 2017       0
# 6  December 29, 2017       0
# 7  December 29, 2017       0
# 8  December 29, 2017       0
# 9  December 28, 2017       0

# %%
# check the if data in files read probably and print first 10 records
Fake_news.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date  label
# 0  December 31, 2017      1
# 1  December 31, 2017      1
# 2  December 30, 2017      1
# 3  December 29, 2017      1
# 4  December 25, 2017      1
# 5  December 25, 2017      1
# 6  December 23, 2017      1
# 7  December 23, 2017      1
# 8  December 22, 2017      1
# 9  December 21, 2017      1

# %%
# create to dataset that holds the feastures that we decide to train on it
dataset1 = True_news[['text','label']]
dataset2 = Fake_news[['text','label']]

# %% [markdown]
# ### **Word Cloud Visualization**

# %%
# create a list of the text data from the 'text' column
text = str(dataset1['text'])

# create a word cloud object
wordcloud = WordCloud().generate(text)

# plot the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# create a list of the text data from the 'text' column
text = str(dataset2['text'])

# create a word cloud object
wordcloud = WordCloud().generate(text)

# plot the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # **Merging Dataset1 and Dataset2 Dataframes**

# %%
# merge dataset1 and dataset2 in one new dataset
dataset = pd.concat([dataset1 , dataset2])

# %%
# dimensions of dataset contaning 44898 columns and 5 rows
dataset.shape
# Out:
# (44898, 2)

# %%
# create a list of the text data from the 'text' column
text = str(dataset['text'])

# create a word cloud object
wordcloud = WordCloud().generate(text)

# plot the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### **Data Distribution**

# %%
def create_distribution(dataFile):
    return sb.countplot(x='label', data=dataFile, palette='hls')

# by calling below we can see that training, test and valid data seems to be failry evenly distributed between the classes
create_distribution(dataset)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
dataset = dataset.dropna()
dataset = dataset.dropna(thresh=2)
dataset.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# ### **Data Quality Check**

# %%
# function help to check data quality 
def data_qualityCheck():
    print("Checking data qualitites..")
    # no null values
    dataset.isnull().sum()
    dataset.info()  
    print("check finished.")
data_qualityCheck()
# Out:
# Checking data qualitites..
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    44898 non-null  object
#  1   label   44898 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ MB
# check finished.

# %% [markdown]
# ### Balanced or Unbalanced dataset

# %%
dataset['label'].value_counts()
# Out:
# 1    23481
# 0    21417
# Name: label, dtype: int64

# %%
# Get the counts of each label
label_counts = dataset['label'].value_counts()

# Create a bar chart
plt.bar(label_counts.index, label_counts.values)
plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Distribution of Labels in Dataset')
plt.show()

# %%
dataset1.shape # true news
# Out:
# (21417, 2)

# %%
dataset2.shape # fake news
# Out:
# (23481, 2)

# %% [markdown]
# ### Shuffle or Resample

# %%
# resample the data
dataset = dataset.sample(frac = 1)

# %%
dataset.head(20)
# Out:
#                                                     text  label
# 4611   Republican presidential nominee Donald Trump r...      1
# 19165        https://www.youtube.com/watch?v=VkRCtn0nEvU      1
# 712    Donald Trump just beat Bill Clinton at somethi...      1
# 3713   WASHINGTON (Reuters) - (This May 17 story, in ...      0
# 1826   Senator Bernie Sanders is the most popular sen...      1
# 685    Well, it s happened. In the manner of every ot...      1
# 3286   Israeli Prime Minister Benjamin Netanyahu thre...      1
# 20394                                                         1
# 5533    WASHINGTON (Reuters) - President Donald Trump...      0
# 13613  CAIRO (Reuters) - Militant group Islamic State...      0
# 21881   If you have a system that rewards you for bei...      1
# 379    The size of Donald Trump s hands seems to be a...      1
# 13446  ANKARA (Reuters) - German Chancellor Angela Me...      0
# 6140   Like a stubborn cold that just doesn t seem to...      1
# 22795  Our weekly documentary screening curated by th...      1
# 1488   Siding with Trump s Attorney General Jeff Sess...      1
# 6183   Since Donald Trump is the presumptive GOP nomi...      1
# 9743   San Juan Mayor Carmen Yulin Cruz tore a book f...      1
# 2333   WASHINGTON/NEW YORK (Reuters) - After a crackd...      0
# 16785  LJUBLJANA (Reuters) - Slovenian President Boru...      0

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of                                                     text  label
# 4611   Republican presidential nominee Donald Trump r...      1
# 19165        https://www.youtube.com/watch?v=VkRCtn0nEvU      1
# 712    Donald Trump just beat Bill Clinton at somethi...      1
# 3713   WASHINGTON (Reuters) - (This May 17 story, in ...      0
# 1826   Senator Bernie Sanders is the most popular sen...      1
# ...                                                  ...    ...
# 6713   (Reuters) - U.S. President-elect Donald Trump ...      0
# 10346  Senator John McCain just couldn t help himself...      1
# 1368   Last week, disgraced former Fox News chief, Ro...      1
# 3759   The appointment of several white supremacists ...      1
# 17443  Yeah putting the federal government in charge ...      1
#
# [44898 rows x 2 columns]>

# %%
dataset.describe()
# Out:
#               label
# count  44898.000000
# mean       0.522985
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# # **Cleaning Data Process**

# %%
ps = WordNetLemmatizer()

# %%
# removing unwanted words in text to improve preformunce 
stopwords = stopwords.words('english')

# %%
def cleaning_data(row):
    
    # convert text to into lower case
    row = row.lower() 
    
    # this line of code only take words from text and remove number and special character using Regular expression
    row = re.sub('[^a-zA-Z]' , ' ' , row)
    
    # split the data and make token.
    token = row.split() 
    
    # lemmatize the word and remove stop words like a, an , the , is ,are ...
    news = [ps.lemmatize(word) for word in token if not word in stopwords]  
    
    # finaly join all the token with space
    cleanned_news = ' '.join(news) 
    
    # return cleanned data
    return cleanned_news

# %%
dataset['text'] = dataset['text'].apply(lambda x : cleaning_data(x)) # apply cleaning_data on the dataset text cloumn

# %%
dataset.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# # **Convert text to vectors**

# %%
# convert text to numerical data can be used in our modules
vectorizer = TfidfVectorizer(max_features = 50000 , lowercase=False , ngram_range=(1,2)) # 1-gram 2- gram combination words

# %%
dataset.shape
# Out:
# (44898, 2)

# %%
X = dataset.iloc[:35000,0] # rows 
y = dataset.iloc[:35000,1] # columns

# %%
X.head()
# Out:
# 4611     republican presidential nominee donald trump r...
# 19165             http www youtube com watch v vkrctn nevu
# 712      donald trump beat bill clinton something embar...
# 3713     washington reuters may story penultimate parag...
# 1826     senator bernie sander popular senator united s...
# Name: text, dtype: object

# %%
y.head()
# Out:
# 4611     1
# 19165    1
# 712      1
# 3713     0
# 1826     1
# Name: label, dtype: int64

# %% [markdown]
# ### **Training and Test Set**

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 ,random_state = 0)

# %%
# First fits the vectorizer to the training data by learning the vocabulary, 
# Transforms the training data into a numerical feature matrix.
# store it in vec_train after converted it to numpy array using toarray() function

vec_train_data = vectorizer.fit_transform(X_train).toarray()

# %%
X_train.shape , X_test.shape
# Out:
# ((28000,), (7000,))

# %%
vec_test_data = vectorizer.transform(X_test).toarray()

# %%
vec_train_data.shape , vec_test_data.shape
# Out:
# ((28000, 50000), (7000, 50000))

# %%
y_train.value_counts() # balanced partition
# Out:
# 1    14602
# 0    13398
# Name: label, dtype: int64

# %%
y_test.value_counts() # balanced partition
# Out:
# 1    3661
# 0    3339
# Name: label, dtype: int64

# %%
# This method returns a list of the feature names that were learned during the fit process, 
# which are essentially the unique words or n-grams that were found in the training data. 
X_training = pd.DataFrame(vec_train_data , columns=vectorizer.get_feature_names_out())
X_testing = pd.DataFrame(vec_test_data , columns= vectorizer.get_feature_names_out())

# %% [markdown]
# # **Logestic Reegression**

# %%
LR = LogisticRegression()
LR.fit(X_training,y_train)
# Out:
# LogisticRegression()

# %%
# Check the number of features in the training and test data
print(f'Number of features in training data: {X_training.shape[1]}')
print(f'Number of features in test data: {X_testing.shape[1]}')
# Out:
# Number of features in training data: 50000
# Number of features in test data: 50000

# %%
# Fit the model to the training data
LR.fit(X_training, y_train)

# Evaluate the model on the test data
accuracy = accuracy_score(y_test, LR.predict(X_testing))
print(f'Test accuracy: {accuracy:.2f}')
# Out:
# Test accuracy: 0.99

# %%
LR.score(X_testing,y_test)
# Out:
# 0.9862857142857143

# %%
pred_LR = LR.predict(X_testing)

# %%
print(classification_report(y_test, pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      3339
#            1       0.99      0.99      0.99      3661
#
#     accuracy                           0.99      7000
#    macro avg       0.99      0.99      0.99      7000
# weighted avg       0.99      0.99      0.99      7000
